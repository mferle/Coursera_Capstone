# %% [markdown]
# ## Coursera Capstone: Segmenting and Clustering Neighborhoods in Toronto
# This project is to explore, segment, and cluster neighborhoods in the city of Toronto.

# %% [markdown]
# ## Introduction
#
# We will start by scraping the Wikipedia page <a href="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M">List of postal codes of Canada: M</a> to get a list of neighborhoods in Toronto. Then we will find the latitude and longitude of each neighborhood. Next, we will use the Foursquare API to explore the neighborhoods. We will get the most common venue categories in each neighborhood, and then use this feature to group the neighborhoods into clusters. We will use the *k*-means clustering algorithm to complete this task. Finally, we will use the Folium library to visualize the neighborhoods in Toronto and their emerging clusters.

# %% [markdown]
# ## Table of Contents
#
# 1. <a href="#toc1">Acquire Data</a>
#
# 2. <a href="#toc2">Explore Neighborhoods in Toronto</a>
#
# 3. <a href="#toc3">Analyze Each Neighborhood</a>
#
# 4. <a href="#toc4">Cluster Neighborhoods</a>
#
# 5. <a href="#toc5">Examine Clusters</a>

# %% [markdown]
# First download all the dependencies that we will need for this analysis.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analysis

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# <a id="toc1"></a>
# ## 1. Acquire Data

# %% [markdown]
# We will scrape the list of Toronto neighborhoods from the Wikipedia page <a href="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M">List of postal codes of Canada: M</a>. Postal codes beginning with M are located within the city of Toronto. Then we will find the geographical coordinates of each post code.

# %% [markdown]
# #### Read data from web page
#
# We will read the page and convert the table into a dataframe using the *pandas* read_html method.

# %%
#get Toronto neighborhoods from Wikipedia page
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
#read the Wikipedia page - returns list of dataframes
dfs = pd.read_html(url, header=0)
#take the first dataframe from the returned list (it should be the only dataframe in the list)
df = dfs[0]
df.head(10)
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M5A  Downtown Toronto       Regent Park
# 6      M6A        North York  Lawrence Heights
# 7      M6A        North York    Lawrence Manor
# 8      M7A      Queen's Park      Not assigned
# 9      M8A      Not assigned      Not assigned

# %% [markdown]
# We will ignore any records where *Borough* is "Not assigned".

# %%
#create new dataframe with records where Borough is not 'Not assigned'
df_assigned = df[df['Borough'] != 'Not assigned']
df_assigned.head(10)
# Out:
#    Postcode           Borough     Neighbourhood
# 2       M3A        North York         Parkwoods
# 3       M4A        North York  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront
# 5       M5A  Downtown Toronto       Regent Park
# 6       M6A        North York  Lawrence Heights
# 7       M6A        North York    Lawrence Manor
# 8       M7A      Queen's Park      Not assigned
# 10      M9A         Etobicoke  Islington Avenue
# 11      M1B       Scarborough             Rouge
# 12      M1B       Scarborough           Malvern

# %% [markdown]
# In rows where the value of *Neighbourhood* is 'Not assigned' we will replace it with the value of the *Borough*.

# %%
#create a list of neighborhoods, replacing the borough where neighborhood is 'Not assigned'
new_neigh = df_assigned['Neighbourhood'].where(df_assigned['Neighbourhood'] != 'Not assigned', other = df_assigned['Borough'], axis = 0)
#construct new dataframe using postcode and borough from the previous dataframe and neighborhood from the above list
df_replaced = pd.concat([df_assigned['Postcode'], df_assigned['Borough'], new_neigh], axis = 1)
df_replaced.head(10)
# Out:
#    Postcode           Borough     Neighbourhood
# 2       M3A        North York         Parkwoods
# 3       M4A        North York  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront
# 5       M5A  Downtown Toronto       Regent Park
# 6       M6A        North York  Lawrence Heights
# 7       M6A        North York    Lawrence Manor
# 8       M7A      Queen's Park      Queen's Park
# 10      M9A         Etobicoke  Islington Avenue
# 11      M1B       Scarborough             Rouge
# 12      M1B       Scarborough           Malvern

# %% [markdown]
# Whenever we have more than one row per postcode, we will concatenate all neighborhoods into a comma separated list

# %%
#group the dataframe by Postcode and Borough and concatenate all neighborhoods into comma separated list
toronto_neighborhoods = df_replaced.groupby(['Postcode', 'Borough'])['Neighbourhood'].apply(list).apply(lambda x: ', '.join(x)).to_frame()
toronto_neighborhoods.reset_index(inplace = True)
toronto_neighborhoods.head(10)
# Out:
#   Postcode      Borough                                    Neighbourhood
# 0      M1B  Scarborough                                   Rouge, Malvern
# 1      M1C  Scarborough           Highland Creek, Rouge Hill, Port Union
# 2      M1E  Scarborough                Guildwood, Morningside, West Hill
# 3      M1G  Scarborough                                           Woburn
# 4      M1H  Scarborough                                        Cedarbrae
# 5      M1J  Scarborough                              Scarborough Village
# 6      M1K  Scarborough      East Birchmount Park, Ionview, Kennedy Park
# 7      M1L  Scarborough                  Clairlea, Golden Mile, Oakridge
# 8      M1M  Scarborough  Cliffcrest, Cliffside, Scarborough Village West
# 9      M1N  Scarborough                      Birch Cliff, Cliffside West

# %%
#display the shape of the resulting dataframe
toronto_neighborhoods.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Assign geographical coordinates
#
# The next step is to assign the geographical coordinates for each postcode. Instructions on the Coursera submission page suggest to use the Geocoder Python package. Unfortunately I was not able to get usable results from this package. As suggested on the submission page, I decided to use the dataset <a href='http://cocl.us/Geospatial_data'>http://cocl.us/Geospatial_data</a> with predefined coordinates per postal code.
#
# There is an alternate way by which we could get coordinates and that would be to use the <a href='https://geopy.readthedocs.io/en/stable/'>GeoPy</a> library with the Nominatim geolocator service (instead of Google Maps). However, this library does not return coordinates based on postal codes but rather on neighborhood names. This would mean that we would have to restructure the above dataframe back to what it was before we concatenated neighborhoods into comma separated values. I decided not to go this way, although I suspect it would have been a viable approach to solving this exercise.

# %%
#read provided dataset
coords = pd.read_csv('http://cocl.us/Geospatial_data')
coords.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# We will merge this dataset with our *toronto_neighborhoods* dataset from above.

# %%
toronto_neighborhoods = pd.merge(toronto_neighborhoods, coords, left_on = 'Postcode', right_on = 'Postal Code')[['Postcode', 'Borough', 'Neighbourhood', 'Latitude', 'Longitude']]
toronto_neighborhoods.head(10)
# Out:
#   Postcode      Borough                                    Neighbourhood  \
# 0      M1B  Scarborough                                   Rouge, Malvern
# 1      M1C  Scarborough           Highland Creek, Rouge Hill, Port Union
# 2      M1E  Scarborough                Guildwood, Morningside, West Hill
# 3      M1G  Scarborough                                           Woburn
# 4      M1H  Scarborough                                        Cedarbrae
# 5      M1J  Scarborough                              Scarborough Village
# 6      M1K  Scarborough      East Birchmount Park, Ionview, Kennedy Park
# 7      M1L  Scarborough                  Clairlea, Golden Mile, Oakridge
# 8      M1M  Scarborough  Cliffcrest, Cliffside, Scarborough Village West
# 9      M1N  Scarborough                      Birch Cliff, Cliffside West
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476
# 5  43.744734 -79.239476
# 6  43.727929 -79.262029
# 7  43.711112 -79.284577
# 8  43.716316 -79.239476
# 9  43.692657 -79.264848

# %%
toronto_neighborhoods.shape
# Out:
# (103, 5)

# %% [markdown]
# ### Add additional data

# %% [markdown]
# #### Number of Elementary and Secondary schools per postal code
#
# We will enrich the previous dataset with information about how many Elementary and Secondary schools there are in each neighborhood by postal code. A list of public schools can be found on the <a href='https://www.ontario.ca/data/ontario-public-school-contact-information'>Ontario public school contact information</a> web site and this list can be transformed into a table with school counts.

# %%
#read the Canada public schools dataset
df = pd.read_excel('https://files.ontario.ca/opendata/publicly_funded_schools_xlsx_january_2019_en.xlsx')

# %% [markdown]
# We will remove the records where the post code is null and we have to filter for postal codes that begin with M - these are the Toronto postal codes. Additionally, we want to keep only the public schools as these are the only ones that we are interested in.

# %%
#keep only rows where the postal code is not null
df = df[df['Postal Code'].notna()]
#keep only rows where the postal code begins with M - these are Toronto postal codes
df = df[df['Postal Code'].str.startswith('M')]
#keep only first 3 characters of postal code
df['Postal Code'] = df['Postal Code'].str[:3]
#keep only public schools
df = df[df['School Type'] == 'Public']

#keep selected columns and store in dataframe called toronto_schools
toronto_schools = df[['School Level', 'School Name', 'Postal Code']]
toronto_schools.head()
# Out:
#     School Level                                 School Name Postal Code
# 540   Elementary                Collège français élémentaire         M5B
# 541    Secondary                 Collège français secondaire         M5B
# 542   Elementary  École élémentaire Académie Alexandre-Dumas         M1E
# 546   Elementary           École élémentaire Charles-Sauriol         M6N
# 551   Elementary             École élémentaire Étienne-Brûlé         M2L

# %% [markdown]
# Next, we want to count how many elementary and how many secondary shools we have in each postal code.

# %%
schools_count = toronto_schools.groupby(['Postal Code', 'School Level']).count().reset_index()
schools_count.columns = ['Postal Code', 'School Level', 'Number of Schools']
schools_count.head()
# Out:
#   Postal Code School Level  Number of Schools
# 0         M1B   Elementary                 16
# 1         M1B    Secondary                  1
# 2         M1C   Elementary                  8
# 3         M1C    Secondary                  2
# 4         M1E   Elementary                 13

# %% [markdown]
# For the analysis we will pivot this dataframe to create columns for school level.

# %%
#perform pivot
schools_count_pivot = schools_count.pivot(index='Postal Code', columns='School Level', values='Number of Schools')
#reset index
schools_count_pivot.reset_index(inplace = True)
#select columns that we need
schools_count_pivot = schools_count_pivot[['Postal Code', 'Elementary', 'Secondary']]
schools_count_pivot.head()
# Out:
# School Level Postal Code  Elementary  Secondary
# 0                    M1B        16.0        1.0
# 1                    M1C         8.0        2.0
# 2                    M1E        13.0        9.0
# 3                    M1G        10.0        2.0
# 4                    M1H         4.0        1.0

# %% [markdown]
# For further analysis we will normalize the school counts. Let's find the maximum school count value and divide each count by this value.

# %%
#find the maximum school count value
max_school_cnt = max(schools_count_pivot['Elementary'].max(), schools_count_pivot['Secondary'].max())

#divide each count by the maximum value
elementary_normalized = schools_count_pivot['Elementary']/max_school_cnt
secondary_normalized = schools_count_pivot['Secondary']/max_school_cnt

#add these columns to the dataframe
schools_count_pivot.insert(schools_count_pivot.shape[1], 'Elementary Normalized', elementary_normalized)
schools_count_pivot.insert(schools_count_pivot.shape[1], 'Secondary Normalized', secondary_normalized)

#drop columns we don't need
schools_count_pivot = schools_count_pivot.drop(['Elementary', 'Secondary'], 1)
schools_count_pivot.head()
# Out:
# School Level Postal Code  Elementary Normalized  Secondary Normalized
# 0                    M1B                 1.0000                0.0625
# 1                    M1C                 0.5000                0.1250
# 2                    M1E                 0.8125                0.5625
# 3                    M1G                 0.6250                0.1250
# 4                    M1H                 0.2500                0.0625

# %% [markdown]
# #### Population count per postal code
#
# We will enrich the dataset by adding population counts for each neighborhood by postal code as published on the Statistics Canada <a href = 'https://www12.statcan.gc.ca/census-recensement/2016/dp-pd/hlt-fst/pd-pl/Table.cfm?Lang=Eng&T=1201&S=22&O=A'>Population and Dwelling Count Highlight Tables, 2016 Census</a> page.
#
# Three values are provided in this table:
# * Population, 2016: represent the number of Canadians whose usual place of residence is in that area, regardless of where they happened to be on census day
# * Total private dwellings, 2016: refers to total private dwellings and private dwellings occupied by usual residents in Canada
# * Private dwellings occupied by usual residents, 2016: refers to usual residents, not including tourists

# %%
#read population data from csv file downloaded from Statistics Canada
df = pd.read_csv('https://raw.githubusercontent.com/mferle/Coursera_Capstone/master/data/T120120190215054507.csv')

#keep only rows where the postal code begins with M - these are Toronto postal codes
df = df[df['Geographic code'].str.startswith('M')]

#remove any columns where the population count is less than 100
df = df[df['Population, 2016'] > 99]

#keep only columns we need for analysis
df = df[['Geographic code', 'Population, 2016', 'Total private dwellings, 2016', 'Private dwellings occupied by usual residents, 2016']]
df.head()
# Out:
#     Geographic code  Population, 2016  Total private dwellings, 2016  \
# 895             M1B             66108                          20957
# 896             M1C             35626                          11588
# 897             M1E             46943                          17637
# 898             M1G             29690                          10116
# 899             M1H             24383                           9274
#
#      Private dwellings occupied by usual residents, 2016
# 895                                              20230
# 896                                              11274
# 897                                              17161
# 898                                               9767
# 899                                               8985

# %% [markdown]
# For the analysis, we are interested in residential areas and therefore we want to exclude tourists which means that our column of interest is *Private dwellings occupied by usual residents, 2016*. We will divide this number by the total population count to derive a percentage of residents as compared to the total population. In residential areas where most of the population is not made up of tourists, the percentage should be higher as elsewhere.

# %%
#calculate percentage and add to dataframe as new column
pct = df['Private dwellings occupied by usual residents, 2016'] / df['Population, 2016']
df.insert(toronto_population.shape[1], 'Percent Occupied', pct)
#drop unwanted columns
toronto_population = df.drop(['Population, 2016', 'Total private dwellings, 2016', 'Private dwellings occupied by usual residents, 2016'], 1)
toronto_population.head()
# Out:
#     Geographic code  Percent Occupied
# 895             M1B          0.306014
# 896             M1C          0.316454
# 897             M1E          0.365571
# 898             M1G          0.328966
# 899             M1H          0.368494

# %% [markdown]
# #### Join school counts and population data with Toronto neighborhoods dataframe

# %%
#join school counts
toronto_neighborhoods = toronto_neighborhoods.join(schools_count_pivot.set_index('Postal Code'), on = 'Postcode')

#replace null values with 0
toronto_neighborhoods['Elementary Normalized'].fillna(0, inplace=True)
toronto_neighborhoods['Secondary Normalized'].fillna(0, inplace=True)
toronto_neighborhoods.head()
# Out:
#   Postcode      Borough                           Neighbourhood   Latitude  \
# 0      M1B  Scarborough                          Rouge, Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3      M1G  Scarborough                                  Woburn  43.770992
# 4      M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude  Elementary Normalized  Secondary Normalized
# 0 -79.194353                 1.0000                0.0625
# 1 -79.160497                 0.5000                0.1250
# 2 -79.188711                 0.8125                0.5625
# 3 -79.216917                 0.6250                0.1250
# 4 -79.239476                 0.2500                0.0625

# %%
#join population data
toronto_neighborhoods = toronto_neighborhoods.join(toronto_population.set_index('Geographic code'), on = 'Postcode')

#replace null values with 0
toronto_neighborhoods['Percent Occupied'].fillna(0, inplace=True)
toronto_neighborhoods.head()
# Out:
#   Postcode      Borough                           Neighbourhood   Latitude  \
# 0      M1B  Scarborough                          Rouge, Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3      M1G  Scarborough                                  Woburn  43.770992
# 4      M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude  Elementary Normalized  Secondary Normalized  Percent Occupied
# 0 -79.194353                 1.0000                0.0625          0.306014
# 1 -79.160497                 0.5000                0.1250          0.316454
# 2 -79.188711                 0.8125                0.5625          0.365571
# 3 -79.216917                 0.6250                0.1250          0.328966
# 4 -79.239476                 0.2500                0.0625          0.368494

# %% [markdown]
# <a id="toc2"></a>
# ## 2. Explore Neighborhoods in Toronto

# %% [markdown]
# Next, we are going to start utilizing the Foursquare API to explore the neighborhoods and segment them.

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# #### Let's explore the first neighborhood in our dataframe

# %% [markdown]
# Find the name, latitude and longitude of the first neighborhood in the dataframe.

# %%
neighborhood_name = toronto_neighborhoods.loc[0, 'Neighbourhood'] # neighborhood name
neighborhood_latitude = toronto_neighborhoods.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = toronto_neighborhoods.loc[0, 'Longitude'] # neighborhood longitude value

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Rouge, Malvern are 43.806686299999996, -79.19435340000001.

# %% [markdown]
# #### Now, let's get the top 100 venues that are in the above neighborhood within a radius of 500 meters

# %% [markdown]
# First we will create the GET request URL.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

# %% [markdown]
# Send the GET request and examine the results

# %%
results = requests.get(url).json()
#results.head()

# %% [markdown]
# We see that all the information that we want is in the *items* key. Before we proceed, we will create the **get_category_type** function which extracts the category name from a JSON object.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
#extract the items key from the results
venues = results['response']['groups'][0]['items']
#flatten JSON into a dataframe
nearby_venues = json_normalize(venues) 
#filter columns that we need for further analysis
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues = nearby_venues.loc[:, filtered_columns]
#extract the category for each row using the previously defined function
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)
# clean columns ?????????????????????????????????????????????
#nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues
# Out:
#   venue.name      venue.categories  venue.location.lat  venue.location.lng
# 0    Wendy's  Fast Food Restaurant           43.807448          -79.199056

# %% [markdown]
# #### Create a function to repeat the same process as above to all the neighborhoods in Toronto

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# The following code executes the above function on each neighborhood and creates a new dataframe called *toronto_venues*.

# %%
toronto_venues = getNearbyVenues(names = toronto_neighborhoods['Neighbourhood'],
                                   latitudes = toronto_neighborhoods['Latitude'],
                                   longitudes = toronto_neighborhoods['Longitude']
                                  )
# Out:
# Rouge, Malvern
# Highland Creek, Rouge Hill, Port Union
# Guildwood, Morningside, West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# East Birchmount Park, Ionview, Kennedy Park
# Clairlea, Golden Mile, Oakridge
# Cliffcrest, Cliffside, Scarborough Village West
# Birch Cliff, Cliffside West
# Dorset Park, Scarborough Town Centre, Wexford Heights
# Maryvale, Wexford
# Agincourt
# Clarks Corners, Sullivan, Tam O'Shanter
# Agincourt North, L'Amoreaux East, Milliken, Steeles East
# L'Amoreaux West, Steeles West
# Upper Rouge
# Hillcrest Village
# Fairview, Henry Farm, Oriole
# Bayview Village
# Silver Hills, York Mills
# Newtonbrook, Willowdale
# Willowdale South
# York Mills West
# Willowdale West
# Parkwoods
# Don Mills North
# Flemingdon Park, Don Mills South
# Bathurst Manor, Downsview North, Wilson Heights
# Northwood Park, York University
# CFB Toronto, Downsview East
# Downsview West
# Downsview Central
# Downsview Northwest
# Victoria Village
# Woodbine Gardens, Parkview Hill
# Woodbine Heights
# The Beaches
# Leaside
# Thorncliffe Park
# East Toronto
# The Danforth West, Riverdale
# The Beaches West, India Bazaar
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park, Summerhill East
# Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West
# Rosedale
# Cabbagetown, St. James Town
# Church and Wellesley
# Harbourfront, Regent Park
# Ryerson, Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Adelaide, King, Richmond
# Harbourfront East, Toronto Islands, Union Station
# Design Exchange, Toronto Dominion Centre
# Commerce Court, Victoria Hotel
# Bedford Park, Lawrence Manor East
# Roselawn
# Forest Hill North, Forest Hill West
# The Annex, North Midtown, Yorkville
# Harbord, University of Toronto
# Chinatown, Grange Park, Kensington Market
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara
# Stn A PO Boxes 25 The Esplanade
# First Canadian Place, Underground city
# Lawrence Heights, Lawrence Manor
# Glencairn
# Humewood-Cedarvale
# Caledonia-Fairbanks
# Christie
# Dovercourt Village, Dufferin
# Little Portugal, Trinity
# Brockton, Exhibition Place, Parkdale Village
# Maple Leaf Park, North Park, Upwood Park
# Del Ray, Keelesdale, Mount Dennis, Silverthorn
# The Junction North, Runnymede
# High Park, The Junction South
# Parkdale, Roncesvalles
# Runnymede, Swansea
# Queen's Park
# Canada Post Gateway Processing Centre
# Business Reply Mail Processing Centre 969 Eastern
# Humber Bay Shores, Mimico South, New Toronto
# Alderwood, Long Branch
# The Kingsway, Montgomery Road, Old Mill North
# Humber Bay, King's Mill Park, Kingsway Park South East, Mimico NE, Old Mill South, The Queensway East, Royal York South East, Sunnylea
# Kingsway Park South West, Mimico NW, The Queensway West, Royal York South West, South of Bloor
# Islington Avenue
# Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park
# Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe
# Humber Summit
# Emery, Humberlea
# Weston
# Westmount
# Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips
# Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown
# Northwest

# %% [markdown]
# Check the size and first few rows of the resulting dataframe

# %%
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (2251, 7)
#                              Neighborhood  Neighborhood Latitude  \
# 0                          Rouge, Malvern              43.806686
# 1  Highland Creek, Rouge Hill, Port Union              43.784535
# 2       Guildwood, Morningside, West Hill              43.763573
# 3       Guildwood, Morningside, West Hill              43.763573
# 4       Guildwood, Morningside, West Hill              43.763573
#
#    Neighborhood Longitude                            Venue  Venue Latitude  \
# 0              -79.194353                          Wendy's       43.807448
# 1              -79.160497            Royal Canadian Legion       43.782533
# 2              -79.188711  Swiss Chalet Rotisserie & Grill       43.767697
# 3              -79.188711                G & G Electronics       43.765309
# 4              -79.188711                 Big Bite Burrito       43.766299
#
#    Venue Longitude        Venue Category
# 0       -79.199056  Fast Food Restaurant
# 1       -79.163085                   Bar
# 2       -79.189914           Pizza Place
# 3       -79.191537     Electronics Store
# 4       -79.190720    Mexican Restaurant

# %% [markdown]
# Count number of appearances of each venue category

# %%
toronto_venues.groupby('Venue Category').count()
# Out:
#                                Neighborhood  Neighborhood Latitude  \
# Venue Category
# Accessories Store                         2                      2
# Adult Boutique                            1                      1
# Afghan Restaurant                         1                      1
# Airport                                   2                      2
# Airport Food Court                        1                      1
# Airport Gate                              1                      1
# Airport Lounge                            2                      2
# Airport Service                           2                      2
# Airport Terminal                          2                      2
# American Restaurant                      34                     34
# Antique Shop                              3                      3
# Aquarium                                  5                      5
# Arepa Restaurant                          1                      1
# Art Gallery                              12                     12
# Art Museum                                2                      2
# Arts & Crafts Store                       6                      6
# Asian Restaurant                         16                     16
# Athletics & Sports                        5                      5
# Auto Garage                               1                      1
# Auto Workshop                             1                      1
# BBQ Joint                                 5                      5
# Baby Store                                2                      2
# Bagel Shop                                6                      6
# Bakery                                   52                     52
# Bank                                     18                     18
# Bar                                      43                     43
# Baseball Field                            5                      5
# Baseball Stadium                          2                      2
# Basketball Court                          1                      1
# Basketball Stadium                        4                      4
# ...                                     ...                    ...
# Stationery Store                          1                      1
# Steakhouse                               21                     21
# Strip Club                                1                      1
# Supermarket                               6                      6
# Supplement Shop                           3                      3
# Sushi Restaurant                         24                     24
# Swim School                               1                      1
# Taco Place                                2                      2
# Tailor Shop                               4                      4
# Taiwanese Restaurant                      1                      1
# Tanning Salon                             1                      1
# Tapas Restaurant                          1                      1
# Tea Room                                 14                     14
# Tennis Court                              1                      1
# Thai Restaurant                          22                     22
# Theater                                  14                     14
# Theme Restaurant                          1                      1
# Thrift / Vintage Store                    3                      3
# Toy / Game Store                          3                      3
# Trail                                     5                      5
# Train Station                             4                      4
# Vegetarian / Vegan Restaurant            14                     14
# Video Game Store                          4                      4
# Video Store                               3                      3
# Vietnamese Restaurant                    13                     13
# Warehouse Store                           1                      1
# Wine Bar                                  9                      9
# Wings Joint                               4                      4
# Women's Store                             4                      4
# Yoga Studio                              11                     11
#
#                                Neighborhood Longitude  Venue  Venue Latitude  \
# Venue Category
# Accessories Store                                   2      2               2
# Adult Boutique                                      1      1               1
# Afghan Restaurant                                   1      1               1
# Airport                                             2      2               2
# Airport Food Court                                  1      1               1
# Airport Gate                                        1      1               1
# Airport Lounge                                      2      2               2
# Airport Service                                     2      2               2
# Airport Terminal                                    2      2               2
# American Restaurant                                34     34              34
# Antique Shop                                        3      3               3
# Aquarium                                            5      5               5
# Arepa Restaurant                                    1      1               1
# Art Gallery                                        12     12              12
# Art Museum                                          2      2               2
# Arts & Crafts Store                                 6      6               6
# Asian Restaurant                                   16     16              16
# Athletics & Sports                                  5      5               5
# Auto Garage                                         1      1               1
# Auto Workshop                                       1      1               1
# BBQ Joint                                           5      5               5
# Baby Store                                          2      2               2
# Bagel Shop                                          6      6               6
# Bakery                                             52     52              52
# Bank                                               18     18              18
# Bar                                                43     43              43
# Baseball Field                                      5      5               5
# Baseball Stadium                                    2      2               2
# Basketball Court                                    1      1               1
# Basketball Stadium                                  4      4               4
# ...                                               ...    ...             ...
# Stationery Store                                    1      1               1
# Steakhouse                                         21     21              21
# Strip Club                                          1      1               1
# Supermarket                                         6      6               6
# Supplement Shop                                     3      3               3
# Sushi Restaurant                                   24     24              24
# Swim School                                         1      1               1
# Taco Place                                          2      2               2
# Tailor Shop                                         4      4               4
# Taiwanese Restaurant                                1      1               1
# Tanning Salon                                       1      1               1
# Tapas Restaurant                                    1      1               1
# Tea Room                                           14     14              14
# Tennis Court                                        1      1               1
# Thai Restaurant                                    22     22              22
# Theater                                            14     14              14
# Theme Restaurant                                    1      1               1
# Thrift / Vintage Store                              3      3               3
# Toy / Game Store                                    3      3               3
# Trail                                               5      5               5
# Train Station                                       4      4               4
# Vegetarian / Vegan Restaurant                      14     14              14
# Video Game Store                                    4      4               4
# Video Store                                         3      3               3
# Vietnamese Restaurant                              13     13              13
# Warehouse Store                                     1      1               1
# Wine Bar                                            9      9               9
# Wings Joint                                         4      4               4
# Women's Store                                       4      4               4
# Yoga Studio                                        11     11              11
#
#                                Venue Longitude
# Venue Category
# Accessories Store                            2
# Adult Boutique                               1
# Afghan Restaurant                            1
# Airport                                      2
# Airport Food Court                           1
# Airport Gate                                 1
# Airport Lounge                               2
# Airport Service                              2
# Airport Terminal                             2
# American Restaurant                         34
# Antique Shop                                 3
# Aquarium                                     5
# Arepa Restaurant                             1
# Art Gallery                                 12
# Art Museum                                   2
# Arts & Crafts Store                          6
# Asian Restaurant                            16
# Athletics & Sports                           5
# Auto Garage                                  1
# Auto Workshop                                1
# BBQ Joint                                    5
# Baby Store                                   2
# Bagel Shop                                   6
# Bakery                                      52
# Bank                                        18
# Bar                                         43
# Baseball Field                               5
# Baseball Stadium                             2
# Basketball Court                             1
# Basketball Stadium                           4
# ...                                        ...
# Stationery Store                             1
# Steakhouse                                  21
# Strip Club                                   1
# Supermarket                                  6
# Supplement Shop                              3
# Sushi Restaurant                            24
# Swim School                                  1
# Taco Place                                   2
# Tailor Shop                                  4
# Taiwanese Restaurant                         1
# Tanning Salon                                1
# Tapas Restaurant                             1
# Tea Room                                    14
# Tennis Court                                 1
# Thai Restaurant                             22
# Theater                                     14
# Theme Restaurant                             1
# Thrift / Vintage Store                       3
# Toy / Game Store                             3
# Trail                                        5
# Train Station                                4
# Vegetarian / Vegan Restaurant               14
# Video Game Store                             4
# Video Store                                  3
# Vietnamese Restaurant                       13
# Warehouse Store                              1
# Wine Bar                                     9
# Wings Joint                                  4
# Women's Store                                4
# Yoga Studio                                 11
#
# [279 rows x 6 columns]

# %% [markdown]
# We see that many venue categories appear only a few times. It doesn't make sense to include these in segmentation because they don't appear often enough to have an impact, but they contribute to noise in the dataset. Therefore we will exclude venue categories that appear less than 5 times from the dataset.
#
# But first, we have to check how many venue categories appear less than 5 times to ensure that we still have enough venue categories left for segmentation.

# %%
#store the results of the above counts into a dataframe
toronto_venues_count = toronto_venues.groupby('Venue Category').count()
print('There are {} venue categories that appear less than 5 times.'.format(toronto_venues_count[toronto_venues_count['Neighborhood'] < 5].shape[0]))
# Out:
# There are 173 venue categories that appear less than 5 times.

# %% [markdown]
# We know that we have a total of 259 venue categories which means that even after we remove 173 of them we should still have sufficient data for segmentation.
#
# Therefore we will exclude the venue categories that appear less than 5 times.

# %%
#create list with neighborhoods to exclude
neigh_to_exclude = toronto_venues_count[toronto_venues_count['Neighborhood'] < 5].index.tolist()
#create filtered dataframe by excluding neighborhoods in above list
toronto_venues_filt = toronto_venues[~toronto_venues['Venue Category'].isin(neigh_to_exclude)]
#check size of resulting dataframe
toronto_venues_filt.groupby('Venue Category').count().shape
# Out:
# (106, 6)

# %% [markdown]
# The number of venue categories is sufficient for further analysis. We will rename the filtered dataset *toronto_venues_filt* back to the original dataset *toronto_venues*.

# %%
toronto_venues = toronto_venues_filt

# %% [markdown]
# <a id="toc3"></a>
# ## 3. Analyze Each Neighborhood
#
# We will do one hot encoding to pivot category values into columns of the dataframe.
#
# There is one observation that we have to be careful about: one of the category values is *Neighborhood*. After one hot encoding, this value will become a column name. We are already using the column *Neighborhood* to represent the neighborhood name. To avoid confusing these columns, we will rename the column that comes from one hot encoding as *Neighborhood Category*.

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

#rename the column 'Neighborhood' which represents a category name to 'Neighborhood Category' 
#this is to distinguish this column from the 'Neighborhood' column which we want to continue to use as the neighborhood name
toronto_onehot.rename(columns={'Neighborhood':'Neighborhood Category'}, inplace=True)

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

#toronto_onehot.head()

# %% [markdown]
# Check the new dataframe size:

# %%
toronto_onehot.shape
# Out:
# (1910, 107)

# %% [markdown]
# #### We will group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped.head(10)
# Out:
#                                         Neighborhood  American Restaurant  \
# 0                           Adelaide, King, Richmond             0.046512
# 1                                          Agincourt             0.000000
# 2  Agincourt North, L'Amoreaux East, Milliken, St...             0.000000
# 3  Albion Gardens, Beaumond Heights, Humbergate, ...             0.000000
# 4                             Alderwood, Long Branch             0.000000
# 5    Bathurst Manor, Downsview North, Wilson Heights             0.000000
# 6                                    Bayview Village             0.000000
# 7                  Bedford Park, Lawrence Manor East             0.045455
# 8                                        Berczy Park             0.000000
# 9                        Birch Cliff, Cliffside West             0.000000
#
#    Aquarium  Art Gallery  Arts & Crafts Store  Asian Restaurant  \
# 0       0.0     0.011628                  0.0          0.034884
# 1       0.0     0.000000                  0.0          0.000000
# 2       0.0     0.000000                  0.0          0.000000
# 3       0.0     0.000000                  0.0          0.000000
# 4       0.0     0.000000                  0.0          0.000000
# 5       0.0     0.000000                  0.0          0.000000
# 6       0.0     0.000000                  0.0          0.000000
# 7       0.0     0.000000                  0.0          0.000000
# 8       0.0     0.020408                  0.0          0.000000
# 9       0.0     0.000000                  0.0          0.000000
#
#    Athletics & Sports  BBQ Joint  Bagel Shop    Bakery     ...       \
# 0                 0.0        0.0    0.000000  0.034884     ...
# 1                 0.0        0.0    0.000000  0.000000     ...
# 2                 0.0        0.0    0.000000  0.000000     ...
# 3                 0.0        0.0    0.000000  0.000000     ...
# 4                 0.0        0.0    0.000000  0.000000     ...
# 5                 0.0        0.0    0.000000  0.000000     ...
# 6                 0.0        0.0    0.000000  0.000000     ...
# 7                 0.0        0.0    0.000000  0.000000     ...
# 8                 0.0        0.0    0.020408  0.040816     ...
# 9                 0.0        0.0    0.000000  0.000000     ...
#
#    Supermarket  Sushi Restaurant  Tea Room  Thai Restaurant   Theater  Trail  \
# 0          0.0          0.023256  0.000000         0.046512  0.011628    0.0
# 1          0.0          0.000000  0.000000         0.000000  0.000000    0.0
# 2          0.0          0.000000  0.000000         0.000000  0.000000    0.0
# 3          0.0          0.000000  0.000000         0.000000  0.000000    0.0
# 4          0.0          0.000000  0.000000         0.000000  0.000000    0.0
# 5          0.0          0.071429  0.000000         0.000000  0.000000    0.0
# 6          0.0          0.000000  0.000000         0.000000  0.000000    0.0
# 7          0.0          0.045455  0.000000         0.045455  0.000000    0.0
# 8          0.0          0.000000  0.020408         0.020408  0.000000    0.0
# 9          0.0          0.000000  0.000000         0.000000  0.000000    0.0
#
#    Vegetarian / Vegan Restaurant  Vietnamese Restaurant  Wine Bar  Yoga Studio
# 0                       0.011628                    0.0  0.011628          0.0
# 1                       0.000000                    0.0  0.000000          0.0
# 2                       0.000000                    0.0  0.000000          0.0
# 3                       0.000000                    0.0  0.000000          0.0
# 4                       0.000000                    0.0  0.000000          0.0
# 5                       0.000000                    0.0  0.000000          0.0
# 6                       0.000000                    0.0  0.000000          0.0
# 7                       0.000000                    0.0  0.000000          0.0
# 8                       0.000000                    0.0  0.000000          0.0
# 9                       0.000000                    0.0  0.000000          0.0
#
# [10 rows x 107 columns]

# %% [markdown]
# Check the new dataframe size:

# %%
toronto_grouped.shape
# Out:
# (97, 107)

# %% [markdown]
# #### Store the above into a *pandas* dataframe

# %% [markdown]
# Write a function to sort the venues in descending order

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Create the new dataframe and display the top 10 venues for each neighborhood

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns = columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                           Adelaide, King, Richmond           Coffee Shop
# 1                                          Agincourt          Skating Rink
# 2  Agincourt North, L'Amoreaux East, Milliken, St...                  Park
# 3  Albion Gardens, Beaumond Heights, Humbergate, ...         Grocery Store
# 4                             Alderwood, Long Branch           Pizza Place
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  Café   American Restaurant       Thai Restaurant
# 1        Breakfast Spot                Lounge        Clothing Store
# 2            Playground                 Diner          Cocktail Bar
# 3  Fast Food Restaurant           Coffee Shop              Pharmacy
# 4          Skating Rink                   Gym              Pharmacy
#
#   5th Most Common Venue    6th Most Common Venue    7th Most Common Venue  \
# 0            Steakhouse         Asian Restaurant                   Bakery
# 1           Yoga Studio              Coffee Shop  Comfort Food Restaurant
# 2           Coffee Shop  Comfort Food Restaurant             Concert Hall
# 3           Pizza Place           Sandwich Place               Beer Store
# 4           Coffee Shop                      Pub           Sandwich Place
#
#   8th Most Common Venue 9th Most Common Venue   10th Most Common Venue
# 0                   Bar                 Hotel                      Gym
# 1          Concert Hall     Convenience Store           Cosmetics Shop
# 2     Convenience Store        Cosmetics Shop                 Creperie
# 3          Liquor Store   Japanese Restaurant           Discount Store
# 4      Department Store          Cocktail Bar  Comfort Food Restaurant

# %%
neighborhoods_venues_sorted.groupby(['1st Most Common Venue']).size()
# Out:
# 1st Most Common Venue
# American Restaurant           1
# Bakery                        1
# Bank                          1
# Bar                           2
# Baseball Field                2
# Beer Store                    1
# Breakfast Spot                1
# Bus Line                      1
# Café                          7
# Chinese Restaurant            3
# Clothing Store                3
# Coffee Shop                  20
# Convenience Store             1
# Discount Store                1
# Fast Food Restaurant          4
# Food Truck                    1
# Fried Chicken Joint           1
# Greek Restaurant              1
# Grocery Store                 4
# Gym                           1
# Gym / Fitness Center          3
# Indian Restaurant             2
# Japanese Restaurant           1
# Mexican Restaurant            2
# Middle Eastern Restaurant     1
# Park                         15
# Pharmacy                      3
# Pizza Place                   6
# Playground                    1
# Pub                           1
# Ramen Restaurant              1
# Skating Rink                  1
# Sporting Goods Shop           1
# Trail                         1
# Yoga Studio                   1
# dtype: int64

# %% [markdown]
# <a id="toc4"></a>
# ## 4. Cluster Neighborhoods

# %% [markdown]
# Run *k*-means to cluster the neighborhood into 5 clusters.

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([3, 3, 0, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 0, 3, 0, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 1, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 1, 4, 3, 2, 3, 3, 3, 3, 3, 3, 0, 3, 3, 0, 3, 3, 3, 3,
#        3, 4, 3, 0, 4, 3, 3, 3, 0, 3, 3, 3, 3, 3, 3, 3, 3, 0, 3, 3, 3, 0, 3,
#        3, 3, 3, 3, 0], dtype=int32)

# %% [markdown]
# Create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = neighborhoods_venues_sorted

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(toronto_neighborhoods.set_index('Neighbourhood'), on='Neighborhood')

toronto_merged.head() # check the last columns!
# Out:
#    Cluster Labels                                       Neighborhood  \
# 0               3                           Adelaide, King, Richmond
# 1               3                                          Agincourt
# 2               0  Agincourt North, L'Amoreaux East, Milliken, St...
# 3               3  Albion Gardens, Beaumond Heights, Humbergate, ...
# 4               3                             Alderwood, Long Branch
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0           Coffee Shop                  Café   American Restaurant
# 1          Skating Rink        Breakfast Spot                Lounge
# 2                  Park            Playground                 Diner
# 3         Grocery Store  Fast Food Restaurant           Coffee Shop
# 4           Pizza Place          Skating Rink                   Gym
#
#   4th Most Common Venue 5th Most Common Venue    6th Most Common Venue  \
# 0       Thai Restaurant            Steakhouse         Asian Restaurant
# 1        Clothing Store           Yoga Studio              Coffee Shop
# 2          Cocktail Bar           Coffee Shop  Comfort Food Restaurant
# 3              Pharmacy           Pizza Place           Sandwich Place
# 4              Pharmacy           Coffee Shop                      Pub
#
#      7th Most Common Venue 8th Most Common Venue           ...             \
# 0                   Bakery                   Bar           ...
# 1  Comfort Food Restaurant          Concert Hall           ...
# 2             Concert Hall     Convenience Store           ...
# 3               Beer Store          Liquor Store           ...
# 4           Sandwich Place      Department Store           ...
#
#     10th Most Common Venue Postcode           Borough   Latitude  Longitude  \
# 0                      Gym      M5H  Downtown Toronto  43.650571 -79.384568
# 1           Cosmetics Shop      M1S       Scarborough  43.794200 -79.262029
# 2                 Creperie      M1V       Scarborough  43.815252 -79.284577
# 3           Discount Store      M9V         Etobicoke  43.739416 -79.588437
# 4  Comfort Food Restaurant      M8W         Etobicoke  43.602414 -79.543484
#
#    Elementary  Secondary  Population 2016  Private dwellings 2016  \
# 0           0          0             2005                    1718
# 1          10          4            37769                   13195
# 2          11          1            54680                   16449
# 3          11          7            55959                   17590
# 4           4          0            20674                    9161
#
#    Occupied dwellings 2016
# 0                     1243
# 1                    12644
# 2                    16092
# 3                    16808
# 4                     8770
#
# [5 rows x 21 columns]

# %% [markdown]
# Visualize the resulting clusters

# %%
address = 'Toronto'
geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Note: because GitHub doesn't display Folium maps, a print screen of the map is available <a href='img/Toronto.png'>here</a>.

# %% [markdown]
# <a id="toc5"></a>
# ## 5. Examine Clusters

# %% [markdown]
# We will examine each cluster and determine the discriminating venue categories that distinguish each cluster. Based on the defining categories, we can then assign a name to each cluster.

# %% [markdown]
# ### Cluster 0: Residential

# %%
toronto_cluster0 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(2, toronto_merged.shape[1]-2))]]
toronto_cluster0
# Out:
#                                          Neighborhood 1st Most Common Venue  \
# 2   Agincourt North, L'Amoreaux East, Milliken, St...                  Park
# 13                        CFB Toronto, Downsview East                  Park
# 15                                Caledonia-Fairbanks                  Park
# 61                                      Lawrence Park                  Park
# 64           Maple Leaf Park, North Park, Upwood Park                  Park
# 72                                           Rosedale                  Park
# 77                           Silver Hills, York Mills                  Park
# 86      The Kingsway, Montgomery Road, Old Mill North                  Park
# 90                                             Weston                  Park
# 96                                    York Mills West                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 2             Playground                 Diner          Cocktail Bar
# 13           Yoga Studio        Clothing Store           Coffee Shop
# 15              Pharmacy  Fast Food Restaurant                 Diner
# 61              Bus Line           Yoga Studio                 Diner
# 64                Bakery           Yoga Studio        Discount Store
# 72            Playground                 Trail          Dessert Shop
# 77           Yoga Studio        Clothing Store           Coffee Shop
# 86           Yoga Studio        Clothing Store           Coffee Shop
# 90           Yoga Studio        Clothing Store           Coffee Shop
# 96                  Bank           Yoga Studio        Discount Store
#
#       5th Most Common Venue    6th Most Common Venue    7th Most Common Venue  \
# 2               Coffee Shop  Comfort Food Restaurant             Concert Hall
# 13  Comfort Food Restaurant             Concert Hall        Convenience Store
# 15             Cocktail Bar              Coffee Shop  Comfort Food Restaurant
# 61              Coffee Shop  Comfort Food Restaurant             Concert Hall
# 64              Coffee Shop  Comfort Food Restaurant             Concert Hall
# 72           Clothing Store             Cocktail Bar              Coffee Shop
# 77  Comfort Food Restaurant             Concert Hall        Convenience Store
# 86  Comfort Food Restaurant             Concert Hall        Convenience Store
# 90  Comfort Food Restaurant             Concert Hall        Convenience Store
# 96              Coffee Shop  Comfort Food Restaurant             Concert Hall
#
#       8th Most Common Venue 9th Most Common Venue 10th Most Common Venue  \
# 2         Convenience Store        Cosmetics Shop               Creperie
# 13           Cosmetics Shop              Creperie          Deli / Bodega
# 15             Concert Hall     Convenience Store         Cosmetics Shop
# 61        Convenience Store        Cosmetics Shop               Creperie
# 64        Convenience Store        Cosmetics Shop               Creperie
# 72  Comfort Food Restaurant          Concert Hall      Convenience Store
# 77           Cosmetics Shop              Creperie          Deli / Bodega
# 86           Cosmetics Shop              Creperie          Deli / Bodega
# 90           Cosmetics Shop              Creperie          Deli / Bodega
# 96        Convenience Store        Cosmetics Shop               Creperie
#
#    Postcode           Borough   Latitude  Longitude  Elementary  Secondary  \
# 2       M1V       Scarborough  43.815252 -79.284577          11          1
# 13      M3K        North York  43.737473 -79.464763           1          1
# 15      M6E              York  43.689026 -79.453512           4          1
# 61      M4N   Central Toronto  43.728020 -79.388790           3          1
# 64      M6L        North York  43.713756 -79.490074           4          0
# 72      M4W  Downtown Toronto  43.679563 -79.377529           1          1
# 77      M2L        North York  43.757490 -79.374714           4          2
# 86      M8X         Etobicoke  43.653654 -79.506944           1          0
# 90      M9N              York  43.706876 -79.518188           4          1
# 96      M2P        North York  43.752758 -79.400049           2          2
#
#     Population 2016
# 2             54680
# 13             5997
# 15            38041
# 61            15330
# 64            20616
# 72            14561
# 77            11717
# 86            10787
# 90            25074
# 96             7843

# %% [markdown]
# The venue categories in this cluster are predominantly shops with some interspersed coffee shops and restaurants as well as parks and sporting venues. It apears that this cluster represents residential areas.

# %% [markdown]
# ### Cluster 1: Ground transportation hub

# %%
toronto_cluster1 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(2, toronto_merged.shape[1]-2))]]
toronto_cluster1
# Out:
#                                          Neighborhood 1st Most Common Venue  \
# 25  Cloverdale, Islington, Martin Grove, Princess ...                  Bank
# 51             Highland Creek, Rouge Hill, Port Union                   Bar
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 25           Yoga Studio     Electronics Store           Coffee Shop
# 51           Yoga Studio     Electronics Store           Coffee Shop
#
#       5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 25  Comfort Food Restaurant          Concert Hall     Convenience Store
# 51  Comfort Food Restaurant          Concert Hall     Convenience Store
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue  \
# 25        Cosmetics Shop              Creperie          Deli / Bodega
# 51        Cosmetics Shop              Creperie          Deli / Bodega
#
#    Postcode      Borough   Latitude  Longitude  Elementary  Secondary  \
# 25      M9B    Etobicoke  43.650943 -79.554724           5          4
# 51      M1C  Scarborough  43.784535 -79.160497           8          2
#
#     Population 2016
# 25            32400
# 51            35626

# %% [markdown]
# The venues in this cluster suggest that it is a transportation hub as it includes bus and metro stations.

# %% [markdown]
# ### Cluster 2: Downtown

# %%
toronto_cluster2 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(2, toronto_merged.shape[1]-2))]]
toronto_cluster2
# Out:
#                                          Neighborhood 1st Most Common Venue  \
# 35                                  Downsview Central            Food Truck
# 40                                   Emery, Humberlea        Baseball Field
# 54  Humber Bay, King's Mill Park, Kingsway Park So...        Baseball Field
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 35        Baseball Field           Yoga Studio        Discount Store
# 40           Yoga Studio     Electronics Store           Coffee Shop
# 54           Yoga Studio     Electronics Store           Coffee Shop
#
#       5th Most Common Venue    6th Most Common Venue 7th Most Common Venue  \
# 35              Coffee Shop  Comfort Food Restaurant          Concert Hall
# 40  Comfort Food Restaurant             Concert Hall     Convenience Store
# 54  Comfort Food Restaurant             Concert Hall     Convenience Store
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue  \
# 35     Convenience Store        Cosmetics Shop               Creperie
# 40        Cosmetics Shop              Creperie          Deli / Bodega
# 54        Cosmetics Shop              Creperie          Deli / Bodega
#
#    Postcode     Borough   Latitude  Longitude  Elementary  Secondary  \
# 35      M3M  North York  43.728496 -79.495697           9          0
# 40      M9M  North York  43.724766 -79.532242           2          3
# 54      M8Y   Etobicoke  43.636258 -79.498509           5          1
#
#     Population 2016
# 35            24046
# 40            22263
# 54            21299

# %% [markdown]
# Most of the neighborhoods in this cluster appear to be geographically located near downtown. The venue categories are predominantly restaurants, coffee shops and hotels with some shops and yoga studios. This is representative of a *Downtown* city area.

# %% [markdown]
# ### Cluster 3: Quick eats

# %%
toronto_cluster3 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(2, toronto_merged.shape[1]-2))]]
toronto_cluster3
# Out:
#                                          Neighborhood  \
# 0                            Adelaide, King, Richmond
# 1                                           Agincourt
# 3   Albion Gardens, Beaumond Heights, Humbergate, ...
# 4                              Alderwood, Long Branch
# 5     Bathurst Manor, Downsview North, Wilson Heights
# 6                                     Bayview Village
# 7                   Bedford Park, Lawrence Manor East
# 8                                         Berczy Park
# 9                         Birch Cliff, Cliffside West
# 10  Bloordale Gardens, Eringate, Markland Wood, Ol...
# 11       Brockton, Exhibition Place, Parkdale Village
# 12  Business Reply Mail Processing Centre 969 Eastern
# 14                        Cabbagetown, St. James Town
# 16              Canada Post Gateway Processing Centre
# 17                                          Cedarbrae
# 18                                 Central Bay Street
# 19          Chinatown, Grange Park, Kensington Market
# 20                                           Christie
# 21                               Church and Wellesley
# 22                    Clairlea, Golden Mile, Oakridge
# 23            Clarks Corners, Sullivan, Tam O'Shanter
# 24    Cliffcrest, Cliffside, Scarborough Village West
# 26                     Commerce Court, Victoria Hotel
# 27                                         Davisville
# 28                                   Davisville North
# 29  Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 30     Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 31           Design Exchange, Toronto Dominion Centre
# 32                                    Don Mills North
# 33  Dorset Park, Scarborough Town Centre, Wexford ...
# ..                                                ...
# 58  Kingsway Park South West, Mimico NW, The Queen...
# 59                      L'Amoreaux West, Steeles West
# 60                   Lawrence Heights, Lawrence Manor
# 62                                            Leaside
# 63                           Little Portugal, Trinity
# 65                                  Maryvale, Wexford
# 66                        Moore Park, Summerhill East
# 67                                 North Toronto West
# 68                    Northwood Park, York University
# 69                             Parkdale, Roncesvalles
# 71                                       Queen's Park
# 74                                 Runnymede, Swansea
# 75                           Ryerson, Garden District
# 76                                Scarborough Village
# 78                                     St. James Town
# 79                    Stn A PO Boxes 25 The Esplanade
# 80                                    Studio District
# 81                The Annex, North Midtown, Yorkville
# 82                                        The Beaches
# 83                     The Beaches West, India Bazaar
# 84                       The Danforth West, Riverdale
# 85                      The Junction North, Runnymede
# 87                                   Thorncliffe Park
# 88                                   Victoria Village
# 89                                          Westmount
# 91                                   Willowdale South
# 92                                    Willowdale West
# 93                                             Woburn
# 94                    Woodbine Gardens, Parkview Hill
# 95                                   Woodbine Heights
#
#         1st Most Common Venue   2nd Most Common Venue  3rd Most Common Venue  \
# 0                 Coffee Shop                    Café    American Restaurant
# 1                Skating Rink          Breakfast Spot                 Lounge
# 3               Grocery Store    Fast Food Restaurant            Coffee Shop
# 4                 Pizza Place            Skating Rink                    Gym
# 5                 Coffee Shop           Deli / Bodega                  Diner
# 6          Chinese Restaurant                    Café    Japanese Restaurant
# 7        Fast Food Restaurant      Italian Restaurant            Coffee Shop
# 8                 Coffee Shop              Restaurant           Cocktail Bar
# 9                        Café            Skating Rink            Yoga Studio
# 10                   Pharmacy            Liquor Store            Pizza Place
# 11                Coffee Shop                    Café         Breakfast Spot
# 12                Yoga Studio    Fast Food Restaurant            Pizza Place
# 14                Coffee Shop              Restaurant            Pizza Place
# 16                Coffee Shop                   Hotel   Gym / Fitness Center
# 17        Fried Chicken Joint                  Bakery   Caribbean Restaurant
# 18                Coffee Shop                    Café     Italian Restaurant
# 19                       Café                     Bar  Vietnamese Restaurant
# 20              Grocery Store                    Café                   Park
# 21        Japanese Restaurant        Sushi Restaurant            Coffee Shop
# 22                   Bus Line                  Bakery                   Park
# 23                Pizza Place                Pharmacy           Noodle House
# 24        American Restaurant            Skating Rink                  Diner
# 26                Coffee Shop                    Café                  Hotel
# 27                Pizza Place            Dessert Shop         Sandwich Place
# 28       Gym / Fitness Center          Breakfast Spot                  Hotel
# 29                        Pub             Coffee Shop    American Restaurant
# 30          Convenience Store              Restaurant         Sandwich Place
# 31                Coffee Shop                    Café                  Hotel
# 32       Gym / Fitness Center    Caribbean Restaurant                   Café
# 33          Indian Restaurant      Chinese Restaurant  Vietnamese Restaurant
# ..                        ...                     ...                    ...
# 58              Grocery Store                  Bakery                    Gym
# 59         Chinese Restaurant    Fast Food Restaurant    Japanese Restaurant
# 60             Clothing Store  Furniture / Home Store  Vietnamese Restaurant
# 62        Sporting Goods Shop             Coffee Shop           Burger Joint
# 63                        Bar             Men's Store             Restaurant
# 65  Middle Eastern Restaurant                  Bakery         Breakfast Spot
# 66                        Gym              Playground                  Trail
# 67             Clothing Store             Coffee Shop    Sporting Goods Shop
# 68                Coffee Shop    Caribbean Restaurant     Miscellaneous Shop
# 69             Breakfast Spot               Gift Shop              Bookstore
# 71                Coffee Shop        Sushi Restaurant                    Gym
# 74                Coffee Shop                    Café            Pizza Place
# 75                Coffee Shop          Clothing Store                   Café
# 76                 Playground             Yoga Studio                  Diner
# 78                Coffee Shop              Restaurant                  Hotel
# 79                Coffee Shop              Restaurant                   Café
# 80                       Café             Coffee Shop    American Restaurant
# 81                       Café          Sandwich Place            Coffee Shop
# 82                Coffee Shop                     Pub           Burger Joint
# 83                       Park                 Brewery           Liquor Store
# 84           Greek Restaurant             Coffee Shop         Ice Cream Shop
# 85                Pizza Place                  Bakery               Bus Line
# 87          Indian Restaurant             Yoga Studio         Sandwich Place
# 88                Coffee Shop            Intersection            Yoga Studio
# 89         Chinese Restaurant             Pizza Place            Coffee Shop
# 91           Ramen Restaurant              Restaurant            Pizza Place
# 92                   Pharmacy             Pizza Place            Coffee Shop
# 93                Coffee Shop             Yoga Studio         Clothing Store
# 94       Fast Food Restaurant             Pizza Place   Gym / Fitness Center
# 95                   Pharmacy      Athletics & Sports         Cosmetics Shop
#
#             4th Most Common Venue    5th Most Common Venue  \
# 0                 Thai Restaurant               Steakhouse
# 1                  Clothing Store              Yoga Studio
# 3                        Pharmacy              Pizza Place
# 4                        Pharmacy              Coffee Shop
# 5                  Sandwich Place      Fried Chicken Joint
# 6                            Bank           Discount Store
# 7             American Restaurant           Sandwich Place
# 8              Italian Restaurant           Farmers Market
# 9                           Diner              Coffee Shop
# 10                           Café               Beer Store
# 11                            Bar                Pet Store
# 12                  Burrito Place               Restaurant
# 14                            Pub                   Bakery
# 16                 Sandwich Place            Burrito Place
# 17                Thai Restaurant       Athletics & Sports
# 18                            Bar             Burger Joint
# 19  Vegetarian / Vegan Restaurant                   Bakery
# 20             Italian Restaurant              Coffee Shop
# 21                     Restaurant             Burger Joint
# 22                   Intersection               Food Truck
# 23            Fried Chicken Joint          Thai Restaurant
# 24                   Cocktail Bar              Coffee Shop
# 26                     Restaurant      American Restaurant
# 27             Seafood Restaurant                 Pharmacy
# 28                           Park           Clothing Store
# 29                    Pizza Place        Convenience Store
# 30                            Bar              Yoga Studio
# 31            American Restaurant               Restaurant
# 32            Japanese Restaurant           Baseball Field
# 33                        Brewery                Pet Store
# ..                            ...                      ...
# 58              Convenience Store             Burger Joint
# 59                       Pharmacy              Pizza Place
# 60                    Coffee Shop      Arts & Crafts Store
# 62                  Grocery Store   Furniture / Home Store
# 63               Asian Restaurant              Coffee Shop
# 65                 Sandwich Place            Shopping Mall
# 66                          Diner             Cocktail Bar
# 67                    Yoga Studio           Sandwich Place
# 68                            Bar           Discount Store
# 69                    Coffee Shop             Burger Joint
# 71                          Diner      Japanese Restaurant
# 74               Sushi Restaurant       Italian Restaurant
# 75      Middle Eastern Restaurant           Cosmetics Shop
# 76                   Cocktail Bar              Coffee Shop
# 78                           Café           Clothing Store
# 79                   Cocktail Bar       Seafood Restaurant
# 80                         Bakery       Italian Restaurant
# 81                    Pizza Place        Indian Restaurant
# 82                    Yoga Studio                    Diner
# 83                 Sandwich Place                      Pub
# 84                      Bookstore       Italian Restaurant
# 85                  Grocery Store      Arts & Crafts Store
# 87                  Grocery Store                      Gym
# 88                 Discount Store  Comfort Food Restaurant
# 89                   Intersection           Sandwich Place
# 91            Japanese Restaurant              Coffee Shop
# 92                  Grocery Store      Arts & Crafts Store
# 93        Comfort Food Restaurant             Concert Hall
# 94                           Bank                Gastropub
# 95                   Skating Rink                     Park
#
#         6th Most Common Venue      7th Most Common Venue  \
# 0            Asian Restaurant                     Bakery
# 1                 Coffee Shop    Comfort Food Restaurant
# 3              Sandwich Place                 Beer Store
# 4                         Pub             Sandwich Place
# 5                    Pharmacy                Pizza Place
# 6     Comfort Food Restaurant               Concert Hall
# 7            Greek Restaurant              Grocery Store
# 8                    Beer Bar         Seafood Restaurant
# 9     Comfort Food Restaurant               Concert Hall
# 10        Fried Chicken Joint           Department Store
# 11                        Gym          Convenience Store
# 12                    Brewery                        Spa
# 14         Italian Restaurant                       Café
# 16        Fried Chicken Joint   Mediterranean Restaurant
# 17                       Bank               Dessert Shop
# 18             Sandwich Place            Bubble Tea Shop
# 19                Coffee Shop         Mexican Restaurant
# 20                  Nightclub          Convenience Store
# 21                       Café                Men's Store
# 22       Fast Food Restaurant                      Diner
# 23         Italian Restaurant       Fast Food Restaurant
# 24    Comfort Food Restaurant               Concert Hall
# 26                 Steakhouse         Italian Restaurant
# 27         Italian Restaurant           Sushi Restaurant
# 28              Grocery Store               Burger Joint
# 29                        Spa                 Bagel Shop
# 30                      Diner                Coffee Shop
# 31                  Gastropub         Italian Restaurant
# 32             Discount Store    Comfort Food Restaurant
# 33               Dessert Shop               Cocktail Bar
# ..                        ...                        ...
# 58             Sandwich Place       Fast Food Restaurant
# 59                Coffee Shop             Sandwich Place
# 60         Miscellaneous Shop                Yoga Studio
# 62              Shopping Mall             Clothing Store
# 63      Vietnamese Restaurant                     Bakery
# 65                Yoga Studio               Dessert Shop
# 66                Coffee Shop    Comfort Food Restaurant
# 67         Chinese Restaurant               Dessert Shop
# 68    Comfort Food Restaurant               Concert Hall
# 69                 Restaurant         Italian Restaurant
# 71               Burger Joint              Burrito Place
# 74                  Gastropub              Smoothie Shop
# 75                Pizza Place           Ramen Restaurant
# 76    Comfort Food Restaurant               Concert Hall
# 78             Cosmetics Shop         Italian Restaurant
# 79                   Beer Bar         Italian Restaurant
# 80    Comfort Food Restaurant  Middle Eastern Restaurant
# 81               Liquor Store             Cosmetics Shop
# 82    Comfort Food Restaurant               Concert Hall
# 83               Burger Joint              Burrito Place
# 84                Yoga Studio                Pizza Place
# 85               Cocktail Bar    Comfort Food Restaurant
# 87               Intersection             Discount Store
# 88               Concert Hall          Convenience Store
# 89  Middle Eastern Restaurant               Dessert Shop
# 91             Sandwich Place                       Café
# 92             Discount Store                   Aquarium
# 93          Convenience Store             Cosmetics Shop
# 94               Intersection                  Pet Store
# 95                 Beer Store        Fried Chicken Joint
#
#         8th Most Common Venue    9th Most Common Venue  \
# 0                         Bar                    Hotel
# 1                Concert Hall        Convenience Store
# 3                Liquor Store      Japanese Restaurant
# 4            Department Store             Cocktail Bar
# 5                  Restaurant         Sushi Restaurant
# 6           Convenience Store           Cosmetics Shop
# 7           Indian Restaurant      Japanese Restaurant
# 8                 Cheese Shop               Steakhouse
# 9           Convenience Store           Cosmetics Shop
# 10                  Gift Shop              Coffee Shop
# 11       Caribbean Restaurant            Burrito Place
# 12             Farmers Market                     Park
# 14                       Park                Pet Store
# 16  Middle Eastern Restaurant      American Restaurant
# 17           Department Store            Deli / Bodega
# 18            Thai Restaurant       Chinese Restaurant
# 19         Chinese Restaurant             Burger Joint
# 20                 Restaurant                    Diner
# 21   Mediterranean Restaurant                Gastropub
# 22                Coffee Shop  Comfort Food Restaurant
# 23         Chinese Restaurant            Deli / Bodega
# 24          Convenience Store           Cosmetics Shop
# 26                        Gym                Gastropub
# 27                       Café              Coffee Shop
# 28             Sandwich Place                      Gym
# 29                 Sports Bar              Supermarket
# 30    Comfort Food Restaurant             Concert Hall
# 31              Deli / Bodega                      Bar
# 32               Concert Hall        Convenience Store
# 33                Coffee Shop  Comfort Food Restaurant
# ..                        ...                      ...
# 58             Discount Store               Food Truck
# 59             Breakfast Spot             Noodle House
# 60                      Diner  Comfort Food Restaurant
# 62               Liquor Store                Pet Store
# 63                Pizza Place                     Café
# 65                Coffee Shop  Comfort Food Restaurant
# 66               Concert Hall        Convenience Store
# 67                      Diner     Fast Food Restaurant
# 68          Convenience Store           Cosmetics Shop
# 69              Movie Theater             Dessert Shop
# 71                       Café                Nightclub
# 74              Burrito Place                 Pharmacy
# 75                 Restaurant                    Diner
# 76          Convenience Store           Cosmetics Shop
# 78                     Bakery                     Park
# 79                      Hotel                      Pub
# 80                  Juice Bar           Ice Cream Shop
# 81                       Park                 Pharmacy
# 82          Convenience Store           Cosmetics Shop
# 83         Italian Restaurant              Pizza Place
# 84               Liquor Store                Juice Bar
# 85               Concert Hall        Convenience Store
# 87               Liquor Store              Coffee Shop
# 88             Cosmetics Shop                 Creperie
# 89               Cocktail Bar  Comfort Food Restaurant
# 91  Middle Eastern Restaurant                   Lounge
# 92    Comfort Food Restaurant             Concert Hall
# 93                   Creperie            Deli / Bodega
# 94                   Pharmacy       Athletics & Sports
# 95          French Restaurant             Cocktail Bar
#
#      10th Most Common Venue Postcode           Borough   Latitude  Longitude  \
# 0                       Gym      M5H  Downtown Toronto  43.650571 -79.384568
# 1            Cosmetics Shop      M1S       Scarborough  43.794200 -79.262029
# 3            Discount Store      M9V         Etobicoke  43.739416 -79.588437
# 4   Comfort Food Restaurant      M8W         Etobicoke  43.602414 -79.543484
# 5      Fast Food Restaurant      M3H        North York  43.754328 -79.442259
# 6                  Creperie      M2K        North York  43.786947 -79.385975
# 7                 Juice Bar      M5M        North York  43.733283 -79.419750
# 8                       Pub      M5E  Downtown Toronto  43.644771 -79.373306
# 9                  Creperie      M1N       Scarborough  43.692657 -79.264848
# 10  Comfort Food Restaurant      M9C         Etobicoke  43.643515 -79.577201
# 11            Grocery Store      M6K      West Toronto  43.636847 -79.428191
# 12               Food Court      M7Y      East Toronto  43.662744 -79.321558
# 14           Sandwich Place      M4X  Downtown Toronto  43.667967 -79.367675
# 16              Supermarket      M7R       Mississauga  43.636966 -79.615819
# 17                 Creperie      M1H       Scarborough  43.773136 -79.239476
# 18              Salad Place      M5G  Downtown Toronto  43.657952 -79.387383
# 19     Caribbean Restaurant      M5T  Downtown Toronto  43.653206 -79.400049
# 20       Athletics & Sports      M6G  Downtown Toronto  43.669542 -79.422564
# 21          Bubble Tea Shop      M4Y  Downtown Toronto  43.665860 -79.383160
# 22             Concert Hall      M1L       Scarborough  43.711112 -79.284577
# 23             Cocktail Bar      M1T       Scarborough  43.781638 -79.304302
# 24                 Creperie      M1M       Scarborough  43.716316 -79.239476
# 26            Deli / Bodega      M5L  Downtown Toronto  43.648198 -79.379817
# 27            Deli / Bodega      M4S   Central Toronto  43.704324 -79.388790
# 28         Asian Restaurant      M4P   Central Toronto  43.712751 -79.390197
# 29         Sushi Restaurant      M4V   Central Toronto  43.686412 -79.400049
# 30           Cosmetics Shop      M6M              York  43.691116 -79.476013
# 31                 Beer Bar      M5K  Downtown Toronto  43.647177 -79.381576
# 32           Cosmetics Shop      M3B        North York  43.745906 -79.352188
# 33             Concert Hall      M1P       Scarborough  43.757410 -79.273304
# ..                      ...      ...               ...        ...        ...
# 58        French Restaurant      M8Z         Etobicoke  43.628841 -79.520999
# 59        Electronics Store      M1W       Scarborough  43.799525 -79.318389
# 60             Concert Hall      M6A        North York  43.718518 -79.464763
# 62                  Brewery      M4G         East York  43.709060 -79.363452
# 63             Cocktail Bar      M6J      West Toronto  43.647927 -79.419750
# 65             Concert Hall      M1R       Scarborough  43.750072 -79.295849
# 66           Cosmetics Shop      M4T   Central Toronto  43.689574 -79.383160
# 67                Gift Shop      M4R   Central Toronto  43.715383 -79.405678
# 68                 Creperie      M3J        North York  43.767980 -79.487262
# 69                     Bank      M6R      West Toronto  43.648960 -79.456325
# 71       Chinese Restaurant      M7A      Queen's Park  43.662301 -79.389494
# 74                      Pub      M6S      West Toronto  43.651571 -79.484450
# 75                    Plaza      M5B  Downtown Toronto  43.657162 -79.378937
# 76                 Creperie      M1J       Scarborough  43.744734 -79.239476
# 78                Gastropub      M5C  Downtown Toronto  43.651494 -79.375418
# 79           Cosmetics Shop      M5W  Downtown Toronto  43.646435 -79.374846
# 80                Gastropub      M4M      East Toronto  43.659526 -79.340923
# 81                      Pub      M5R   Central Toronto  43.672710 -79.405678
# 82                 Creperie      M4E      East Toronto  43.676357 -79.293031
# 83           Ice Cream Shop      M4L      East Toronto  43.668999 -79.315572
# 84        Indian Restaurant      M4K      East Toronto  43.679557 -79.352188
# 85           Cosmetics Shop      M6N              York  43.673185 -79.487262
# 87                 Pharmacy      M4H         East York  43.705369 -79.349372
# 88            Deli / Bodega      M4A        North York  43.725882 -79.315572
# 89             Concert Hall      M9P         Etobicoke  43.696319 -79.532242
# 91                 Pharmacy      M2N        North York  43.770120 -79.408493
# 92        Convenience Store      M2R        North York  43.782736 -79.442259
# 93         Department Store      M1G       Scarborough  43.770992 -79.216917
# 94               Bagel Shop      M4B         East York  43.706397 -79.309937
# 95              Coffee Shop      M4C         East York  43.695344 -79.318389
#
#     Elementary  Secondary  Population 2016
# 0            0          0             2005
# 1           10          4            37769
# 3           11          7            55959
# 4            4          0            20674
# 5            5          1            37011
# 6            3          0            23852
# 7            4          0            25975
# 8            1          0             9118
# 9            7          1            22136
# 10           9          1            38291
# 11           4          1            40957
# 12           0          0               10
# 14           2          0            20822
# 16           0          0                0
# 17           4          1            24383
# 18           2          3             8423
# 19           7          5            17748
# 20           8          4            32086
# 21           1          4            30472
# 22           6          1            35081
# 23          10          1            34588
# 24           7          1            22913
# 26           0          0                0
# 27           3          0            26506
# 28           2          3            20039
# 29           2          0            18241
# 30          11          7            42434
# 31           0          0                0
# 32           3          1            13324
# 33           7          7            45571
# ..         ...        ...              ...
# 58           1          0            17038
# 59          11          3            48471
# 60           3          3            21048
# 62           4          1            19076
# 63           8          0            32684
# 65           7          5            29858
# 66           2          0            10463
# 67           2          1            11394
# 68           4          1            25473
# 69           3          0            19857
# 71           0          0               10
# 74           5          1            34299
# 75           1          2            12785
# 76           5          0            36699
# 78           0          0             2951
# 79           0          0               15
# 80           6          3            24689
# 81           3          0            26496
# 82           6          1            25044
# 83           6          0            32640
# 84           7          3            31583
# 85          11          1            41243
# 87           2          0            19688
# 88           5          0            14443
# 89           3          2            20874
# 91           8          2            75897
# 92           6          3            40792
# 93          10          2            29690
# 94           5          1            18628
# 95           8          4            46866
#
# [79 rows x 18 columns]

# %% [markdown]
# The venues in this cluster are predominantly restaurants/fast food restaurants and similar and this suggests that it is an area for grabbing something quick to eat.

# %% [markdown]
# ### Cluster 4: Airport

# %%
toronto_cluster4 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(2, toronto_merged.shape[1]-2))]]
toronto_cluster4
# Out:
#          Neighborhood 1st Most Common Venue     2nd Most Common Venue  \
# 52  Hillcrest Village  Fast Food Restaurant  Mediterranean Restaurant
# 70          Parkwoods                  Park      Fast Food Restaurant
# 73     Rouge, Malvern  Fast Food Restaurant               Yoga Studio
#
#    3rd Most Common Venue 4th Most Common Venue    5th Most Common Venue  \
# 52           Yoga Studio        Discount Store              Coffee Shop
# 70           Yoga Studio                 Diner              Coffee Shop
# 73        Discount Store           Coffee Shop  Comfort Food Restaurant
#
#       6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 52  Comfort Food Restaurant          Concert Hall     Convenience Store
# 70  Comfort Food Restaurant          Concert Hall     Convenience Store
# 73             Concert Hall     Convenience Store        Cosmetics Shop
#
#    9th Most Common Venue 10th Most Common Venue Postcode      Borough  \
# 52        Cosmetics Shop               Creperie      M2H   North York
# 70        Cosmetics Shop               Creperie      M3A   North York
# 73              Creperie          Deli / Bodega      M1B  Scarborough
#
#      Latitude  Longitude  Elementary  Secondary  Population 2016
# 52  43.803762 -79.363452          10          1            24497
# 70  43.753259 -79.329656          10          2            34615
# 73  43.806686 -79.194353          16          1            66108

# %% [markdown]
# This cluster is obviously an airport.

# %% [markdown]
# # Discussion

# %%
#neighborhoods that have been flagged as best to live in
df = pd.read_excel('https://github.com/mferle/Coursera_Capstone/blob/master/data/Top_blogs.xlsx?raw=true')
df['Top16'].fillna(0, inplace=True)
df['Top10'].fillna(0, inplace=True)
df['Top8'].fillna(0, inplace=True)
df = df.astype({'Top16' : int, 'Top10' : int, 'Top8' : int})
toronto_flagged = df
toronto_flagged.head()
# Out:
#   Postal Code  Top16  Top10  Top8
# 0         M4E      0      1     1
# 1         M4L      1      0     0
# 2         M4P      1      1     1
# 3         M4S      1      1     1
# 4         M4X      1      1     0

# %%
tf = toronto_flagged.join(toronto_neighborhoods.set_index('Postcode'), on = 'Postal Code')
tf.head()
# Out:
#   Postal Code  Top16  Top10  Top8           Borough  \
# 0         M4E      0      1     1      East Toronto
# 1         M4L      1      0     0      East Toronto
# 2         M4P      1      1     1   Central Toronto
# 3         M4S      1      1     1   Central Toronto
# 4         M4X      1      1     0  Downtown Toronto
#
#                     Neighbourhood   Latitude  Longitude  Elementary  \
# 0                     The Beaches  43.676357 -79.293031           6
# 1  The Beaches West, India Bazaar  43.668999 -79.315572           6
# 2                Davisville North  43.712751 -79.390197           2
# 3                      Davisville  43.704324 -79.388790           3
# 4     Cabbagetown, St. James Town  43.667967 -79.367675           2
#
#    Secondary  Population 2016  Private dwellings 2016  Occupied dwellings 2016
# 0          1            25044                   11284                    10784
# 1          0            32640                   14634                    13901
# 2          3            20039                   12207                    11487
# 3          0            26506                   14011                    13397
# 4          0            20822                   10809                    10306

# %%
# create map
map_best = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(tf['Latitude'], tf['Longitude'], tf['Neighbourhood'], tf['Top16']):
  if cluster == 1:
    label = folium.Popup(str(poi) + ' Top16 ', parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=9,
        popup=label,
        color=rainbow[1],
        fill=True,
        fill_color=rainbow[1],
        fill_opacity=0.7).add_to(map_best)
for lat, lon, poi, cluster in zip(tf['Latitude'], tf['Longitude'], tf['Neighbourhood'], tf['Top10']):
  if cluster == 1:
    label = folium.Popup(str(poi) + ' Top10 ', parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=7,
        popup=label,
        color=rainbow[2],
        fill=True,
        fill_color=rainbow[2],
        fill_opacity=0.7).add_to(map_best)
for lat, lon, poi, cluster in zip(tf['Latitude'], tf['Longitude'], tf['Neighbourhood'], tf['Top8']):
  if cluster == 1:
    label = folium.Popup(str(poi) + ' Top8 ', parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[3],
        fill=True,
        fill_color=rainbow[3],
        fill_opacity=0.7).add_to(map_best)
       
map_best
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
